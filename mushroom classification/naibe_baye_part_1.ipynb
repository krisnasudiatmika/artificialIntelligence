# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()

# %%
ds = df.apply(le.fit_transform)

# %%
ds
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# 5         0          5            3          9        1     0
# 6         0          0            2          8        1     0
# 7         0          0            3          8        1     3
# 8         1          5            3          8        1     6
# 9         0          0            2          9        1     0
# 10        0          5            3          9        1     3
# 11        0          5            3          9        1     0
# 12        0          0            2          9        1     0
# 13        1          5            3          8        1     6
# ...

# %%
data = ds.values
print(data[:,1])
# Out:
# [5 5 0 ... 2 3 5]

# %%
data_X = data[:,1:]

# %%
data_X
# Out:
# array([[5, 2, 4, ..., 2, 3, 5],
#        [5, 2, 9, ..., 3, 2, 1],
#        [0, 2, 8, ..., 3, 2, 3],
#        ...,
#        [2, 2, 4, ..., 0, 1, 2],
#        [3, 3, 4, ..., 7, 4, 2],
#        [5, 2, 4, ..., 4, 1, 2]])

# %%
data_X.shape
# Out:
# (8124, 22)

# %%
data_Y = data[:,0]

# %%
data_Y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
 x_train, x_test, y_train, y_test = train_test_split(data_X, data_Y, test_size = 0.2)

# %%
np.unique(y_train)
# Out:
# array([0, 1])

# %%
def prior_prob(y_train, label):
    total = y_train.shape[0]
    class_examples = np.sum(y_train == label)
    return (class_examples) / float(total)

# %%
Y = np.array([0,1,0, 1,0,0,1,1,1,1])

# %%
prior_prob(Y,1)
# Out:
# 0.6

# %%
def cond_prob(x_train, y_train, feature_col, feature_val, label):
    x_filtered = x_train[y_train == label]
    generator = np.sum(x_filtered[:, feature_col] == feature_val)
    denominator = np.sum(y_train == label)
    return generator / float(denominator)

# %%
def predict(x_train, y_train, xtest):
    classes = np.unique(y_train)
    n_features = x_train.shape[1]
    posterior_proba = []
    for label in classes:
        likehood = 1
        for f in range(n_features):
            conditional = cond_prob(x_train, y_train,f, xtest[f], label)
            likehood = likehood * conditional
        prior = prior_prob(y_train, label)
        post = likehood * prior
        posterior_proba.append(post)
    pred = np.argmax(posterior_proba)
    return pred

# %%
print(x_test[100])
# Out:
# [2 2 2 0 2 1 0 1 0 1 0 2 2 7 6 0 2 1 0 7 4 2]

# %%
output = predict(x_train, y_train, x_test[100])

# %%
print(output)
# Out:
# 1

# %%
print(y_test[100])
# Out:
# 1

# %%
def score(x_train, y_train, x_test, y_test):
    pred= []
    for i in range(x_test.shape[0]):
        pred_label = predict(x_train, y_train, x_test[i])
        pred.append(pred_label)
    pred = np.array(pred)
    accuracy = np.sum(pred == y_test)/y_test.shape[0]
    return accuracy

# %%
print(score(x_train, y_train, x_test,y_test))
# Out:
# 0.9975384615384615
